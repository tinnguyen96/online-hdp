# %% [markdown]
# # Held-out log-likelihood

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## SB-LDA versus LDA 1/K across mini-batch iterations

# %%
def fixDfixK_sbVSlda(K, D, inroot, heldoutroot, expset):
    """
    Inputs:
        K: approximation level
        D: mini-batch size 
        expset: list of experimental seeds
    Outputs:
        plots LL of LDA 1/K and SB_LDA versus number of minibatches
    Remarks: 
        all experiments are expected to run until completion i.e. 
        the same number of iterations.
    """
    
    # Load and compute average LDA 1/K
    ldadir = "results/ldaK" + str(K) + "_" + "D" + str(D) + "_" + inroot + "_" + heldoutroot
    ldaLL = []
    ## load experiments
    for seed in expset:
        ldapath = ldadir + "/LL_" + str(seed) + ".csv"
        result = np.loadtxt(ldapath)
        ldabatchcounts = result[:,0]
        ldaLL.append(result[:,2])
    ldaLL = np.array(ldaLL) # shape len(expset) x maxbatchcount
    ldaavg = np.mean(ldaLL, axis=0) # shape (maxbatchcount,)
    ldaerr = np.std(ldaLL, axis=0) # shape (maxbatchcount,)
    
    # Load and compute average SB_LDA
    sbdir = "results/sbldaK" + str(K) + "_" + "D" + str(D) + "_" + inroot + "_" + heldoutroot
    sbLL = []
    ## load experiments
    for seed in expset:
        sbpath = sbdir + "/LL_" + str(seed) + ".csv"
        result = np.loadtxt(sbpath)
        sbbatchcounts = result[:,0]
        sbLL.append(result[:,2])
    sbLL = np.array(sbLL) # shape len(expset) x len(batchcounts)
    sbavg = np.mean(sbLL, axis=0) # shape (len(batchcounts),)
    sberr = np.std(sbLL, axis=0) # shape (len(batchcounts),)
    
    fig = plt.figure()
    plt.errorbar(ldabatchcounts, ldaavg, yerr=ldaerr,label='LDA 1/K')
    plt.errorbar(sbbatchcounts, sbavg, yerr=sberr,label='SB-LDA')
    plt.title('K = %d, D = %d' %(K,D))
    plt.xlabel('Number of mini-batches')
    plt.ylabel('Held-out log-likelihood')
    plt.legend()
    plt.show()
    
    return

# %%
compare_sbVSlda(100, 16, "wiki10k","wiki1k", range(5,10))

# %% [markdown]
# ## SB-LDA versus LDA 1/K for varying K

# %%
def varyK_sbVSlda(Klist, D, inroot, heldoutroot, expset, ax):
    """
    Inputs:
        Klist: list of approximation levels
        D: scalar, mini-batch size 
        expset: list of experimental seeds
        ax: axis to plot
    Outputs:
        plots LL of LDA 1/K and SB_LDA versus number of minibatches
    Remarks: 
        all experiments are expected to run until completion i.e. 
        the same number of iterations.
    """
    lda = {}
    lda['avg'] = []
    lda['err'] = []
    sblda = {}
    sblda['avg'] = []
    sblda['err'] = []
    for i in range(len(Klist)):
        K = Klist[i]
        
        # average held-out log-likelihood at convergence of LDA 1/K
        ldadir = "results/ldaK" + str(K) + "_" + "D" + str(D) + "_" + inroot + "_" + heldoutroot
        finalldaLL = []
        ## load experiments
        for seed in expset:
            ldapath = ldadir + "/LL_" + str(seed) + ".csv"
            result = np.loadtxt(ldapath)
            # extract only LL at convergence
            finalldaLL.append(result[-1,2])
        finalldaLL = np.array(finalldaLL) # shape (len(expset),)
        lda['avg'].append(np.mean(finalldaLL)) # scalar
        lda['err'].append(np.std(finalldaLL)) # scalar
    
        # average held-out log-likelihood at convergence of LDA 1/K

        sbdir = "results/sbldaK" + str(K) + "_" + "D" + str(D) + "_" + inroot + "_" + heldoutroot
        finalsbLL = []
        ## load experiments
        for seed in expset:
            sbpath = sbdir + "/LL_" + str(seed) + ".csv"
            result = np.loadtxt(sbpath)
            # extract only LL at convergence 
            finalsbLL.append(result[-1,2])
        finalsbLL = np.array(finalsbLL) # shape (len(expset),)
        sblda['avg'].append(np.mean(finalsbLL)) # scalar
        sblda['err'].append(np.std(finalsbLL)) # scalar
        
        
    ax.errorbar(Klist, lda['avg'], yerr=lda['err'],label='LDA 1/K')
    
    ax.errorbar(Klist, sblda['avg'], yerr=sblda['err'],label='SB-LDA')
    
    ax.set_title('D = %d' %(D))
    ax.set_xlabel('Number of topics K')
    ax.set_ylabel('Held-out log-likelihood at convergence')
    ax.legend()
    
    return

# %%
Klist = range(10,100,10)
Dlist = [20, 50, 100]

fig, axes = plt.subplots(1,3,figsize=(12,4))

for i in range(3):
    varyK_sbVSlda(Klist, Dlist[i], "wiki10k","wiki1k", range(0,5), axes[i])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## compare among SB-LDA for fixed D but varying K

# %%
def sb_acrossK(Klist, D, inroot, heldoutroot, expset, ax, plot_error):
    """
    Inputs:
        Klist: approximation levels
        D: mini-batch size 
        inroot:
        heldoutroot:
        expset: dictionary of experimental seeds, keys being approximation levels in Klist 
        ax: axis to plot
        plot_error: whether to plot error bars
    Outputs:
        plots LL of SB_LDA versus number of minibatches for different K's
    """
    
    sbavg = []
    sberr = []
    
    for i in range(len(Klist)):
        K = Klist[i]
        seeds = expset[K]
        sbdir = "results/sbldaK" + str(K) + "_" + "D" + str(D) + "_" + inroot + "_" + heldoutroot
        sbLL = []
        for seed in seeds:
            sbpath = sbdir + "/LL_" + str(seed) + ".csv"
            result = np.loadtxt(sbpath)
            sbbatchcounts = result[:,0]
            sbLL.append(result[:,2])
        sbLL = np.array(sbLL) # shape len(expset) x len(batchcounts)
        sbavg.append(np.mean(sbLL, axis=0)) # shape (len(batchcounts),)
        sberr.append(np.std(sbLL, axis=0)) # shape (len(batchcounts),)
    
    for i in range(len(Klist)):
        if (plot_error):
            ax.errorbar(sbbatchcounts, sbavg[i], yerr=sberr[i],label='K = %d' %Klist[i])
        else:
            ax.plot(sbbatchcounts, sbavg[i],label='K = %d' %Klist[i])
    ax.set_title('SB-LDA, D = %d' %D)
    ax.set_xlabel('Number of mini-batches')
    ax.set_ylabel('Held-out log-likelihood')
    ax.legend()
    return

# %%
Klist = [50, 100, 150]
inroot = "wiki10k"
heldoutroot = "wiki1k"
expset = {50:[0,1,2,3,4], 100:[0,1,2,3,4], 150:[0,1,2,3,4]}
plot_error = True
fig, axes = plt.subplots(2,3,figsize=(12,8))

D = [16, 50, 100]
for i in range(3):
    sb_acrossK(Klist, D[i], inroot, heldoutroot, expset, axes[0,i], True)
    sb_acrossK(Klist, D[i], inroot, heldoutroot, expset, axes[1,i], False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Effect of batch size on SB-LDA

# %%
def sb_acrossD(K, Dlist, inroot, heldoutroot, expset, ax, plot_error):
    """
    Inputs:
        K: approximation level
        Dlist: mini-batch sizes
        inroot:
        heldoutroot:
        expset: dictionary of experimental seeds, keys being minibatch sizes in Dlist
        ax: axis to plot
        plot_error: whether to plot error bars
    Outputs:
        plots LL of SB_LDA versus number of minibatches for different K's
    """
    
    sbexs = [] # number of training examples processed
    sbavg = []
    sberr = []
    
    for i in range(len(Dlist)):
        D = Dlist[i]
        seeds = expset[D]
        sbdir = "results/sbldaK" + str(K) + "_" + "D" + str(D) + "_" + inroot + "_" + heldoutroot
        sbLL = []
        for seed in seeds:
            sbpath = sbdir + "/LL_" + str(seed) + ".csv"
            result = np.loadtxt(sbpath)
            sbbatchcounts = result[:,0]
            sbLL.append(result[:,2])
        sbbatchcounts = np.array(sbbatchcounts)
        sbexs.append(D*sbbatchcounts)
        sbLL = np.array(sbLL) # shape len(expset) x len(batchcounts)
        sbavg.append(np.mean(sbLL, axis=0)) # shape (len(batchcounts),)
        sberr.append(np.std(sbLL, axis=0)) # shape (len(batchcounts),)
    
    for i in range(len(Dlist)):
        if (plot_error):
            ax.errorbar(sbexs[i], sbavg[i], yerr=sberr[i],label='D = %d' %Dlist[i])
        else:
            ax.plot(sbexs[i], sbavg[i], label='D = %d' %Dlist[i])
    ax.set_title('SB-LDA, K = %d' %K)
    ax.set_xlabel('Number of training examples processed')
    ax.set_ylabel('Held-out log-likelihood')
    ax.legend()
    return

# %%
K = [50, 100, 150]
Dlist = [20, 50, 100]
inroot = "wiki10k"
heldoutroot = "wiki1k"
expset = {20:[0,1,2,3,4], 50:[0,1,2,3,4], 100:[0,1,2,3,4]}
fig, axes = plt.subplots(2,3,figsize=(12,8))

for i in range(3):
    sb_acrossD(K[i], Dlist, inroot, heldoutroot, expset, axes[0,i], True)
    sb_acrossD(K[i], Dlist, inroot, heldoutroot, expset, axes[1,i], False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Effect of batch size on LDA 1/K

# %%
def lda_acrossD(K, Dlist, inroot, heldoutroot, expset, ax, plot_error):
    """
    Inputs:
        K: approximation level
        Dlist: mini-batch sizes
        inroot:
        heldoutroot:
        expset: dictionary of experimental seeds, keys being minibatch sizes in Dlist
        ax: axis to plot
        plot_error: whether to plot error bars
    Outputs:
        plots LL of LDA versus number of minibatches for different K's
    """
    
    exs = {} # number of training examples processed
    avg = {} # average LL 
    err = {} # standard deviation in LL
    
    for i in range(len(Dlist)):
        D = Dlist[i]
        seeds = expset[D]
        dirname = "results/ldaK" + str(K) + "_" + "D" + str(D) + "_" + inroot + "_" + heldoutroot
        LL = []
        # assuming that all seeds ran for the same number of iterations
        for seed in seeds:
            path = dirname + "/LL_" + str(seed) + ".csv"
            result = np.loadtxt(path)
            batchcounts = result[:,0]
            LL.append(result[:,2])
        batchcounts = np.array(batchcounts)
        exs[D] = D*batchcounts
        LL = np.array(LL) # shape len(expset) x len(batchcounts)
        avg[D] = np.mean(LL, axis=0) # shape (len(batchcounts),)
        err[D] = np.std(LL, axis=0) # shape (len(batchcounts),)
    
    for i in range(len(Dlist)):
        D = Dlist[i]
        if (plot_error):
            ax.errorbar(exs[D], avg[D], yerr=err[D],label='D = %d' %D)
        else:
            ax.plot(exs[D], avg[D], label='D = %d' %D)
    ax.set_title('LDA 1/K, K = %d' %K)
    ax.set_xlabel('Number of training examples processed')
    ax.set_ylabel('Held-out log-likelihood')
    ax.legend()
    return

# %%
K = [50, 100, 150]
Dlist = [20, 50, 100]
inroot = "wiki10k"
heldoutroot = "wiki1k"
expset = {20:[0,1,2,3,4], 50:[0,1,2,3,4], 100:[0,1,2,3,4]}

fig, axes = plt.subplots(2,3,figsize=(12,8))
for i in range(3):
    lda_acrossD(K[i], Dlist, inroot, heldoutroot, expset, axes[0,i], True)
    lda_acrossD(K[i], Dlist, inroot, heldoutroot, expset, axes[1,i], False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Inferred topics

# %%
import numpy as np
import pandas as pd

# %%
from utils import GEM_expectation
import matplotlib.pyplot as plt

def printtopics(vocabfile, file, method, normalized, threshold, displaycount):
    """
    Inputs:
    Outputs:
    """
    vocab = open(vocabfile).readlines()
    testlambda = np.loadtxt(file["lambda"])
    # compute expectation of topic's underlying probability
    testa = np.loadtxt(file["a"])
    if (method == "thdp"):
        testb = np.loadtxt(file["b"]) 
        probs = GEM_expectation(testa[np.newaxis,:],testb[np.newaxis,:]).flatten()
    elif (method == "nhdp"):
        probs = testa/np.sum(testa)
        
    # plot the expectations
    plt.figure()
    plt.plot(probs,marker="o")
    plt.title("Expected underlying proportions")
    plt.xlabel("Topic index")
    plt.ylabel("Underlying proportions")
    plt.show()
    
    sigtopics = 0
    df = pd.DataFrame() 
    for k in range(0, len(testlambda)):
        lambdak = list(testlambda[k, :])
        lambdak = [round(i,1) for i in lambdak]
        # report marginal probabilities instead of Dirichlet parameters
        if (normalized):
            lambdak = lambdak / sum(lambdak)
        temp = list(zip(lambdak, list(range(0, len(lambdak)))))
        temp = sorted(temp, key = lambda x: x[0], reverse=True)
        # plot topics with parameters exceeding the threshold
        if (temp[0][0] >= threshold):
            colname = 'topic %d: prob %.2f' % (k, probs[k])
            coldata = [(str.strip(vocab[temp[i][1]]), temp[i][0]) for i in range(0, displaycount)]
            df[colname] = coldata
    print("Discovered %d significant topics at threshold %.2f" %(len(df.columns),threshold))
    return df

# %% [markdown]
# ### T_HDP output with no topic ordering

# %%
vocabfile = "dictnostops.txt"
file = {}
file["lambda"] ="results/thdpK100_D50_wiki10k_wiki1k/lambda-400.dat"
file["a"] ="results/thdpK100_D50_wiki10k_wiki1k/a-400.dat"
file["b"] ="results/thdpK100_D50_wiki10k_wiki1k/b-400.dat"
normalized = False
method = "thdp"
threshold = 50
displaycount = 10
df = printtopics(vocabfile, file, method, normalized, threshold, displaycount)
df
# Out:
# Discovered 5 significant topics at threshold 50.00
#   topic 35: prob 0.00    topic 84: prob 0.00  topic 87: prob 0.01  \
# 0       (draw, 326.5)         (italy, 130.2)    (district, 759.2)
# 1       (hard, 125.9)   (architecture, 99.7)      (county, 480.4)
# 2       (clay, 125.3)         (design, 85.9)  (population, 466.1)
# 3      (draws, 110.6)    (competition, 63.6)     (village, 424.7)
# 4        (anna, 72.2)       (magazine, 55.4)    (province, 387.9)
# 5       (julia, 48.6)            (new, 43.8)       (rural, 337.2)
# 6       (laura, 36.0)         (venice, 41.6)     (central, 195.3)
# 7      (united, 34.4)            (art, 33.2)      (poland, 155.5)
# 8         (mas, 30.0)  (international, 30.4)   (elevation, 145.3)
# 9      (states, 29.6)       (national, 30.3)   (districts, 137.2)
#
#   topic 98: prob 0.03 topic 99: prob 0.97
# 0   (species, 1197.5)    (score, 10527.4)
# 1      (line, 1046.6)      (new, 10447.6)
# 2       (two, 1014.5)     (first, 9964.7)
# 3     (system, 851.5)      (team, 8906.8)
# 4    (station, 780.5)       (two, 6475.3)
# 5        (new, 747.3)     (years, 5901.0)
# 6      (first, 723.1)      (time, 5469.1)
# 7      (found, 678.2)    (school, 5318.1)
# 8       (high, 659.5)     (march, 5196.0)
# 9       (time, 657.2)      (year, 5140.9)

# %% [markdown]
# ### T_HDP with topic ordering but slightly incorrect E-step due to expect_log_sticks

# %%
vocabfile = "dictnostops.txt"
file = {}
file["lambda"] ="results/thdpK100_D20_wiki10k_wiki1k/lambda-400.dat"
file["a"] ="results/thdpK100_D20_wiki10k_wiki1k/a-400.dat"
file["b"] ="results/thdpK100_D20_wiki10k_wiki1k/b-400.dat"
normalized = False
method = "thdp"
threshold = 200
displaycount = 10
df = printtopics(vocabfile, file, method, normalized, threshold, displaycount)
df
# Out:
# Discovered 28 significant topics at threshold 200.00
#    topic 0: prob 0.07 topic 1: prob 0.05    topic 2: prob 0.04  \
# 0       (new, 4132.3)      (new, 1773.2)         (new, 1842.6)
# 1     (first, 2604.4)      (two, 1354.7)       (first, 1413.6)
# 2    (school, 2005.4)     (best, 1020.4)  (university, 1140.8)
# 3      (city, 1665.2)     (time, 1018.3)    (american, 1022.5)
# 4       (two, 1630.5)     (music, 988.0)          (two, 850.3)
# 5      (york, 1460.3)      (song, 864.9)          (law, 831.8)
# 6     (state, 1449.0)      (live, 829.5)       (states, 814.2)
# 7      (time, 1447.1)     (japan, 827.4)       (school, 789.7)
# 8      (road, 1427.4)      (work, 813.0)        (state, 783.6)
# 9  (american, 1367.0)     (three, 810.8)       (jewish, 746.0)
#
#     topic 3: prob 0.03   topic 4: prob 0.02 topic 5: prob 0.02  \
# 0      (march, 4068.0)        (new, 1002.8)    (goals, 1936.0)
# 1        (gen, 2412.6)      (school, 826.7)    (years, 1768.9)
# 2   (regiment, 2144.1)       (power, 800.0)     (team, 1469.7)
# 3    (colonel, 1866.3)       (first, 773.4)    (first, 1440.7)
# 4  (september, 1739.1)        (area, 752.2)   (season, 1374.6)
# 5    (october, 1715.7)       (state, 688.2)    (clubs, 1288.5)
# 6        (new, 1538.0)  (population, 682.3)     (club, 1201.5)
# 7      (first, 1527.2)        (high, 668.8)   (league, 1152.9)
# 8      (april, 1499.0)         (two, 610.6)       (new, 956.5)
# 9      (value, 1490.3)        (city, 601.0)    (career, 824.2)
#
#   topic 6: prob 0.01    topic 7: prob 0.01 topic 8: prob 0.01  \
# 0     (john, 1851.3)       (score, 8036.1)     (team, 1292.5)
# 1     (lord, 1488.3)        (team, 4216.4)     (round, 914.7)
# 2  (william, 1155.2)       (goals, 2015.8)     (first, 647.5)
# 3       (sir, 922.8)        (seed, 1544.2)    (season, 643.0)
# 4     (henry, 840.2)  (attendance, 1151.8)     (score, 550.5)
# 5    (george, 817.9)      (report, 1078.7)      (mens, 483.5)
# 6   (general, 799.8)       (result, 906.5)      (seed, 474.2)
# 7   (charles, 787.1)         (yard, 672.5)       (won, 467.3)
# 8  (february, 551.2)       (points, 500.9)     (final, 425.4)
# 9      (july, 533.7)        (round, 395.0)     (event, 419.7)
#
#   topic 9: prob 0.01  ... topic 25: prob 0.01 topic 31: prob 0.01  \
# 0      (ship, 930.4)  ...    (species, 220.4)      (major, 230.4)
# 1   (station, 393.7)  ...      (family, 94.4)        (nest, 76.3)
# 2      (line, 230.7)  ...       (snake, 93.5)       (first, 44.1)
# 3     (ships, 161.4)  ...   (described, 88.5)         (oak, 40.7)
# 4   (service, 153.4)  ...       (found, 84.8)     (species, 35.2)
# 5   (railway, 144.5)  ...       (genus, 79.4)     (workers, 32.9)
# 6       (war, 131.0)  ...   (australia, 74.3)        (food, 32.7)
# 7     (glory, 120.7)  ...       (black, 64.2)     (meaning, 31.4)
# 8    (border, 117.3)  ...       (brown, 50.2)       (three, 30.1)
# 9     (fleet, 115.4)  ...        (head, 37.7)        (prey, 27.6)
#
#   topic 38: prob 0.00 topic 42: prob 0.01 topic 49: prob 0.01  \
# 0        (air, 313.5)        (fat, 654.2)       (sign, 221.7)
# 1   (squadron, 237.0)      (studio, 73.1)        (horn, 62.3)
# 2        (base, 93.0)       (first, 36.3)       (power, 42.1)
# 3       (force, 91.4)       (music, 30.1)       (trail, 31.6)
# 4  (operations, 71.4)         (day, 29.6)       (texas, 30.3)
# 5       (group, 57.7)         (mud, 25.6)     (speaker, 25.1)
# 6     (defense, 48.9)        (book, 17.7)    (increase, 24.4)
# 7      (combat, 36.0)        (asks, 16.1)        (game, 23.5)
# 8        (july, 34.6)     (mexican, 14.7)    (governor, 23.1)
# 9      (august, 34.0)         (mad, 14.3)     (forward, 22.6)
#
#   topic 77: prob 0.01 topic 87: prob 0.01 topic 88: prob 0.02  \
# 0       (neat, 207.5)       (town, 463.0)       (week, 828.9)
# 1        (data, 47.4)     (county, 348.8)      (color, 398.2)
# 2         (aux, 31.4)    (meeting, 145.1)       (match, 57.0)
# 3       (faces, 28.5)     (council, 84.7)        (mens, 45.6)
# 4        (mars, 27.4)      (region, 84.2)         (san, 38.5)
# 5      (refuge, 27.0)      (bridge, 78.9)       (world, 31.1)
# 6         (als, 26.6)         (new, 76.9)  (california, 27.2)
# 7    (research, 22.8)       (river, 57.2)       (state, 26.9)
# 8         (var, 22.5)       (mayor, 50.4)       (davis, 25.1)
# 9         (day, 21.1)       (south, 39.0)       (place, 17.8)
#
#   topic 90: prob 0.01 topic 94: prob 0.01
# 0        (max, 222.4)  (alexander, 234.2)
# 1      (louise, 80.5)       (books, 41.3)
# 2        (sign, 60.6)       (major, 38.9)
# 3        (deaf, 37.9)       (facts, 38.4)
# 4       (color, 25.5)         (des, 33.9)
# 5         (new, 23.0)    (scottish, 33.4)
# 6       (opera, 21.9)        (work, 31.4)
# 7      (secret, 19.4)    (american, 31.4)
# 8        (mine, 17.9)        (jean, 27.0)
# 9        (site, 16.7)      (france, 26.1)
#
# [10 rows x 28 columns]

# %% [markdown]
# ### T_HDP with topic ordering, slightly incorrect E-step due to expect_log_sticks, ran for almost 1000 mini-batches

# %%
vocabfile = "dictnostops.txt"
file = {}
file["lambda"] ="results/thdpK100_D20_wiki10k_wiki1k/lambda-800.dat"
file["a"] ="results/thdpK100_D20_wiki10k_wiki1k/a-800.dat"
file["b"] ="results/thdpK100_D20_wiki10k_wiki1k/b-800.dat"
normalized = False
method = "thdp"
threshold = 200
displaycount = 10
df = printtopics(vocabfile, file, method, normalized, threshold, displaycount)
df
# Out:
# Discovered 13 significant topics at threshold 200.00
#    topic 0: prob 0.43 topic 1: prob 0.05   topic 2: prob 0.03  \
# 0       (new, 9980.1)    (japan, 1668.2)         (new, 564.9)
# 1     (first, 8301.4)     (live, 1197.7)  (university, 559.8)
# 2       (two, 6036.8)   (action, 1018.1)       (first, 481.5)
# 3    (school, 4807.5)       (new, 644.3)    (research, 477.1)
# 4    (county, 4792.6)      (song, 586.6)      (social, 396.6)
# 5      (time, 4597.5)      (best, 576.6)       (state, 385.7)
# 6  (american, 4515.2)     (music, 555.1)     (support, 381.5)
# 7      (city, 4102.1)       (two, 552.3)       (based, 379.3)
# 8      (year, 4013.1)  (released, 513.1)    (national, 367.1)
# 9     (years, 3984.3)      (name, 476.3)      (states, 350.0)
#
#    topic 3: prob 0.02 topic 4: prob 0.01   topic 5: prob 0.01  \
# 0     (march, 2413.2)    (goals, 2137.6)  (population, 471.5)
# 1       (gen, 1561.7)    (years, 1688.3)        (town, 302.9)
# 2  (regiment, 1296.8)    (clubs, 1601.4)    (district, 253.6)
# 3   (colonel, 1283.2)     (team, 1515.2)        (area, 248.5)
# 4    (league, 1001.7)   (league, 1144.0)         (age, 229.5)
# 5   (infantry, 995.7)   (season, 1095.8)      (school, 219.2)
# 6  (volunteer, 931.5)      (club, 891.2)         (new, 199.0)
# 7  (september, 885.3)       (cup, 842.9)     (village, 188.4)
# 8    (october, 871.4)    (played, 686.5)       (state, 185.0)
# 9     (season, 864.0)     (first, 638.3)      (island, 183.2)
#
#     topic 6: prob 0.00 topic 7: prob 0.00 topic 8: prob 0.00  \
# 0      (score, 9852.1)      (john, 412.9)      (team, 570.1)
# 1       (team, 3933.6)       (sir, 277.1)     (score, 462.5)
# 2       (seed, 2640.8)   (william, 218.1)      (seed, 244.4)
# 3       (goals, 486.7)      (lord, 173.1)     (round, 221.1)
# 4  (attendance, 381.8)   (charles, 163.5)     (first, 175.5)
# 5      (report, 331.5)    (george, 163.0)    (season, 138.0)
# 6       (round, 230.9)     (henry, 149.0)     (world, 134.1)
# 7      (result, 207.4)      (hall, 115.7)      (mens, 127.9)
# 8         (won, 165.2)       (son, 115.2)       (won, 124.1)
# 9      (points, 145.0)      (duke, 114.3)     (event, 111.0)
#
#   topic 9: prob 0.00  topic 10: prob 0.00 topic 13: prob 0.00  \
# 0      (ship, 669.5)    (district, 468.8)   (election, 280.9)
# 1     (ships, 146.0)  (population, 315.9)    (results, 255.4)
# 2   (station, 129.7)      (county, 306.6)    (general, 253.2)
# 3    (service, 79.2)    (province, 277.3)       (size, 228.9)
# 4       (navy, 64.5)     (village, 257.2)       (lead, 226.4)
# 5       (line, 61.2)       (rural, 247.9)        (con, 225.4)
# 6      (fleet, 52.2)     (central, 132.0)      (green, 102.4)
# 7      (class, 44.6)      (poland, 118.7)         (nov, 44.5)
# 8    (railway, 40.2)    (elevation, 97.3)         (oct, 41.8)
# 9      (march, 38.4)        (south, 95.2)         (feb, 40.0)
#
#   topic 17: prob 0.01
# 0       (week, 529.0)
# 1      (color, 324.2)
# 2         (oct, 28.1)
# 3         (san, 19.5)
# 4  (california, 15.9)
# 5       (state, 14.8)
# 6        (mens, 12.8)
# 7       (santa, 10.9)
# 8      (george, 10.5)
# 9        (davis, 9.7)

# %% [markdown]
# ### T_HDP with topic ordering, corrected E-step, ran for a small number of mini-batches

# %%
vocabfile = "dictnostops.txt"
file = {}
file["lambda"] ="results/thdpK100_T20_D50_wiki10k_wiki1k/lambda-100.dat"
file["a"] ="results/thdpK100_T20_D50_wiki10k_wiki1k/a-100.dat"
file["b"] ="results/thdpK100_T20_D50_wiki10k_wiki1k/b-100.dat"
normalized = False
method = "thdp"
threshold = 200
displaycount = 10
df = printtopics(vocabfile, file, method, normalized, threshold, displaycount)
df
# Out:
# Discovered 7 significant topics at threshold 200.00
#      topic 0: prob 0.63 topic 1: prob 0.19 topic 2: prob 0.11  \
# 0         (new, 4563.7)    (first, 2311.6)     (road, 1950.1)
# 1       (first, 3694.5)   (season, 2275.8)     (town, 1349.7)
# 2    (american, 3014.6)     (team, 2158.4)   (county, 1318.1)
# 3  (university, 2630.7)    (goals, 2123.5)  (district, 955.4)
# 4       (state, 2537.8)    (years, 2052.6)      (line, 951.1)
# 5         (two, 2294.5)     (year, 2029.2)    (street, 931.4)
# 6        (city, 2289.5)   (series, 1761.8)   (species, 616.6)
# 7      (states, 2269.3)      (two, 1708.6)     (south, 546.2)
# 8       (march, 2251.8)     (game, 1497.0)      (east, 513.2)
# 9        (time, 2238.6)   (played, 1407.8)     (river, 510.9)
#
#   topic 3: prob 0.01 topic 4: prob 0.00  topic 6: prob 0.00 topic 9: prob 0.00
# 0    (score, 1535.7)    (score, 2967.2)      (week, 1151.4)    (bridge, 207.7)
# 1      (team, 471.5)     (team, 1473.4)      (color, 650.5)       (aux, 103.9)
# 2     (cells, 129.9)     (seed, 1239.3)        (con, 315.6)     (avenue, 47.1)
# 3       (cell, 59.7)     (round, 150.7)       (lead, 286.9)     (nelson, 37.3)
# 4       (seed, 56.3)        (van, 76.0)    (results, 178.2)      (trail, 31.3)
# 5   (attitude, 54.9)      (first, 63.1)   (election, 156.5)       (lake, 14.5)
# 6      (birds, 48.8)     (second, 38.8)         (nov, 97.4)       (rail, 12.7)
# 7     (theory, 48.7)       (mark, 38.7)         (oct, 75.1)      (local, 12.7)
# 8     (league, 41.4)       (fall, 31.9)         (feb, 35.7)       (city, 12.0)
# 9        (two, 40.7)       (clay, 31.5)  (california, 34.2)    (chicago, 10.9)

# %%
vocabfile = "dictnostops.txt"
file = {}
file["lambda"] ="results/thdpK100_T20_D50_wiki10k_wiki1k/lambda-200.dat"
file["a"] ="results/thdpK100_T20_D50_wiki10k_wiki1k/a-200.dat"
file["b"] ="results/thdpK100_T20_D50_wiki10k_wiki1k/b-200.dat"
normalized = False
method = "thdp"
threshold = 200
displaycount = 10
df = printtopics(vocabfile, file, method, normalized, threshold, displaycount)
df
# Out:
# Discovered 7 significant topics at threshold 200.00
#    topic 0: prob 0.68 topic 1: prob 0.18   topic 2: prob 0.09  \
# 0     (march, 8512.1)     (team, 4063.0)     (county, 2146.6)
# 1       (new, 7837.3)   (season, 3307.1)       (road, 1851.4)
# 2     (first, 5339.7)    (goals, 3154.7)   (district, 1196.9)
# 3       (gen, 5165.5)    (first, 2935.8)       (lake, 1099.8)
# 4   (colonel, 4060.4)    (years, 2823.6)        (town, 952.2)
# 5  (regiment, 4033.4)     (year, 2509.6)     (species, 856.6)
# 6  (american, 3904.7)   (league, 2248.5)     (village, 733.9)
# 7     (state, 3698.5)     (game, 2135.6)  (population, 681.7)
# 8      (john, 3695.2)      (two, 2043.1)        (line, 674.8)
# 9       (two, 3647.9)     (club, 2006.6)       (south, 631.5)
#
#   topic 3: prob 0.00  topic 4: prob 0.01  topic 5: prob 0.01  \
# 0    (score, 4759.1)  (september, 422.7)      (score, 858.4)
# 1     (team, 1948.1)       (neat, 323.8)       (team, 307.5)
# 2     (seed, 1290.7)    (october, 313.6)  (alexander, 127.4)
# 3     (round, 202.2)      (value, 253.7)       (cells, 67.0)
# 4     (first, 108.8)       (sort, 244.7)      (rested, 65.5)
# 5        (van, 97.3)       (data, 225.7)       (match, 54.9)
# 6     (second, 54.7)     (august, 191.4)       (value, 50.4)
# 7        (won, 49.9)   (november, 162.9)        (ring, 46.8)
# 8       (mark, 48.3)      (mount, 161.6)        (cell, 43.0)
# 9      (final, 42.9)   (december, 158.0)        (wing, 39.1)
#
#   topic 6: prob 0.00
# 0      (week, 564.9)
# 1  (election, 503.0)
# 2       (con, 497.3)
# 3      (lead, 484.7)
# 4   (results, 474.9)
# 5     (color, 334.3)
# 6      (size, 321.9)
# 7   (general, 262.0)
# 8       (nov, 122.5)
# 9       (oct, 102.6)

# %% [markdown]
# ### N_HDP, corrected E-step, small number of mini-batches

# %%
vocabfile = "dictnostops.txt"
file = {}
file["lambda"] ="results/nhdpK100_T20_D50_wiki10k_wiki1k/lambda-100.dat"
file["a"] ="results/nhdpK100_T20_D50_wiki10k_wiki1k/a-100.dat"
file["b"] ="results/nhdpK100_T20_D50_wiki10k_wiki1k/b-100.dat"
normalized = False
method = "nhdp"
threshold = 200
displaycount = 10
df = printtopics(vocabfile, file, method, normalized, threshold, displaycount)
df
# Out:
# Discovered 6 significant topics at threshold 200.00
#   topic 39: prob -4.22    topic 46: prob -2.59 topic 48: prob -5.45  \
# 0      (female, 233.6)           (year, 708.4)       (week, 1329.3)
# 1     (species, 152.7)           (race, 341.6)       (color, 533.9)
# 2    (favorite, 107.9)            (top, 337.7)       (match, 122.7)
# 3        (love, 102.2)       (finished, 318.2)        (state, 34.6)
# 4          (top, 82.1)           (army, 315.7)         (mask, 32.6)
# 5         (best, 77.2)           (july, 298.6)          (san, 27.7)
# 6        (genus, 69.9)           (left, 294.0)        (first, 25.7)
# 7       (format, 66.4)  (international, 268.5)   (california, 24.9)
# 8         (year, 63.3)          (board, 257.5)        (santa, 22.6)
# 9      (chapter, 61.1)       (american, 245.3)          (man, 20.7)
#
#   topic 58: prob -3.54  topic 68: prob -0.48 topic 82: prob -3.37
# 0      (score, 5222.2)       (first, 5774.8)      (county, 956.3)
# 1       (team, 2955.3)         (new, 5721.5)        (road, 799.4)
# 2       (seed, 1337.8)         (two, 3991.8)        (town, 767.8)
# 3  (attendance, 522.7)        (time, 3283.6)  (population, 502.4)
# 4      (report, 388.3)       (years, 3243.3)    (district, 460.1)
# 5      (result, 344.0)    (american, 2928.4)     (village, 306.4)
# 6       (match, 308.5)       (state, 2908.2)      (bridge, 300.8)
# 7       (goals, 289.9)  (university, 2868.1)         (age, 266.3)
# 8       (round, 273.8)      (school, 2800.6)       (rural, 228.4)
# 9       (final, 255.9)       (world, 2634.9)     (meeting, 202.1)

# %% [markdown]
# # Warm-start

# %% [markdown]
# ## Train LDA 1/K using SB-LDA topics

# %%
def lda_warm(K, Dlist, inroot, heldoutroot, topicpath, expset, ax, plot_error, plot_cold):
    """
    Inputs:
        K: approximation level
        Dlist: batch sizes; should always contain only positive numbers
        inroot: "wiki10k"
        heldoutroot: "wiki1k"
        topicpath: "results/sbldaK100_D16_wiki10k_wiki1k/lambda-300", for instance
        expset: dictionary of experimental seeds, keys being minibatch sizes in Dlist
        ax: axis to plot
        plot_error: whether to plot error bars
        plot_cold: whether to plot a representative cold-start training 
    Outputs:
        plots warm-start LDA 1/K's LL (vs number of training examples) for the different 
        minibatch sizes in Dlist. For context, also plot cold-start LL. 
    """
    
    exs = {} # number of training examples processed; 
    exs[0] = 0 # exs[0] keep track of maximum number of training examples ever-processed across batch sizes
    avg = {} # average LL 
    err = {} # standard deviation in LL
    
    # warm-start results
    for i in range(len(Dlist)):
        D = Dlist[i]
        seeds = expset[D]
        dirname = "results/ldaK" + str(K) + "_" + "D" + str(D) + "_" + inroot + "_" + heldoutroot \
                    + "/warm/" + topicpath
        LL = []
        for seed in seeds:
            path = dirname + "/LL_" + str(seed) + ".csv"
            result = np.loadtxt(path)
            batchcounts = result[:,0]
            LL.append(result[:,2])
        batchcounts = np.array(batchcounts)
        exs[D] = D*batchcounts
        exs[0] = max(exs[0],max(exs[D]))
        LL = np.array(LL) # shape len(expset) x len(batchcounts)
        avg[D] = np.mean(LL, axis=0) # shape (len(batchcounts),)
        err[D] = np.std(LL, axis=0) # shape (len(batchcounts),)
    for i in range(len(Dlist)):
        D = Dlist[i]
        if (plot_error):
            ax.errorbar(exs[D], avg[D], yerr=err[D],label='D = %d' %D)
        else:
            ax.plot(exs[D], avg[D], label='D = %d' %D)
    
    if (plot_cold):
        # representative cold-start
        dirname = "results/ldaK" + str(K) + "_" + "D" + str(Dlist[-1]) + "_" + inroot + "_" + heldoutroot
        LL = []
        seeds = expset[Dlist[-1]]
        for seed in seeds:
            path = dirname + "/LL_" + str(seed) + ".csv"
            result = np.loadtxt(path)
            batchcounts = result[:,0]
            LL.append(result[:,2])
        batchcounts = np.array(batchcounts)
        cold_exs = D*batchcounts
        LL = np.array(LL) # shape len(expset) x len(batchcounts)
        cold_avg = np.mean(LL, axis=0) # shape (len(batchcounts),)
        cold_err = np.std(LL, axis=0) # shape (len(batchcounts),)
        ## find the right range of training examples to plot both cold and warm results
        indices = cold_exs <= exs[0]

        if (plot_error):
            ax.errorbar(cold_exs[indices], cold_avg[indices], yerr=cold_err[indices], \
                        linestyle='--',label='cold, D = %d' %Dlist[-1])
        else:
            ax.plot(cold_exs[indices], cold_avg[indices], linestyle='--', \
                    label='cold, D = %d' %Dlist[-1])
    
    ax.set_title('LDA 1/K, K = %d \n %s' %(K,topicpath))
    ax.set_xlabel('Number of training examples processed')
    ax.set_ylabel('Held-out log-likelihood')
    ax.legend()
    return

# %%
K = 100
Dlist = [5, 10, 20]
inroot = "wiki10k"
heldoutroot = "wiki1k"
topicpath = "results/sbldaK100_D16_wiki10k_wiki1k/lambda-300"
expset = {5:[0,1,2,3,4], 10:[0,1,2,3,4], 20:[0,1,2,3,4]}

fig, axes = plt.subplots(2,2,figsize=(12,8))
lda_warm(K, Dlist, inroot, heldoutroot, topicpath, expset, axes[0,0], True, True)
lda_warm(K, Dlist, inroot, heldoutroot, topicpath, expset, axes[0,1], False, True)
lda_warm(K, Dlist, inroot, heldoutroot, topicpath, expset, axes[1,0], True, False)
lda_warm(K, Dlist, inroot, heldoutroot, topicpath, expset, axes[1,1], False, False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Train SB-LDA using LDA 1/K topics

# %%
def sblda_warm(K, Dlist, inroot, heldoutroot, topicpath, expset, ax, plot_error, plot_cold):
    """
    Inputs:
        K: approximation level
        Dlist: batch sizes; should always contain only positive numbers
        inroot: "wiki10k"
        heldoutroot: "wiki1k"
        topicpath: "results/sbldaK100_D16_wiki10k_wiki1k/lambda-300", for instance
        expset: dictionary of experimental seeds, keys being minibatch sizes in Dlist
        ax: axis to plot
        plot_error: whether to plot error bars
        plot_cold: whether to plot a representative cold-start training 
    Outputs:
        plots warm-start SB-LDA 1/K's LL (vs number of training examples) for the different 
        minibatch sizes in Dlist. For context, also plot cold-start LL. 
    """
    
    exs = {} # number of training examples processed; 
    exs[0] = 0 # exs[0] keep track of maximum number of training examples ever-processed across batch sizes
    avg = {} # average LL 
    err = {} # standard deviation in LL
    
    # warm-start results
    for i in range(len(Dlist)):
        D = Dlist[i]
        seeds = expset[D]
        dirname = "results/sbldaK" + str(K) + "_" + "D" + str(D) + "_" + inroot + "_" + heldoutroot \
                    + "/warm/" + topicpath
        LL = []
        for seed in seeds:
            path = dirname + "/LL_" + str(seed) + ".csv"
            result = np.loadtxt(path)
            batchcounts = result[:,0]
            LL.append(result[:,2])
        batchcounts = np.array(batchcounts)
        exs[D] = D*batchcounts
        exs[0] = max(exs[0],max(exs[D]))
        LL = np.array(LL) # shape len(expset) x len(batchcounts)
        avg[D] = np.mean(LL, axis=0) # shape (len(batchcounts),)
        err[D] = np.std(LL, axis=0) # shape (len(batchcounts),)
    for i in range(len(Dlist)):
        D = Dlist[i]
        if (plot_error):
            ax.errorbar(exs[D], avg[D], yerr=err[D],label='D = %d' %D)
        else:
            ax.plot(exs[D], avg[D], label='D = %d' %D)
    
    if (plot_cold):
        # representative cold-start
        dirname = "results/sbldaK" + str(K) + "_" + "D" + str(Dlist[-1]) + "_" + inroot + "_" + heldoutroot
        LL = []
        seeds = expset[Dlist[-1]]
        for seed in seeds:
            path = dirname + "/LL_" + str(seed) + ".csv"
            result = np.loadtxt(path)
            batchcounts = result[:,0]
            LL.append(result[:,2])
        batchcounts = np.array(batchcounts)
        cold_exs = D*batchcounts
        LL = np.array(LL) # shape len(expset) x len(batchcounts)
        cold_avg = np.mean(LL, axis=0) # shape (len(batchcounts),)
        cold_err = np.std(LL, axis=0) # shape (len(batchcounts),)
        ## find the right range of training examples to plot both cold and warm results
        indices = cold_exs <= exs[0]

        if (plot_error):
            ax.errorbar(cold_exs[indices], cold_avg[indices], yerr=cold_err[indices], \
                        linestyle='--',label='cold, D = %d' %Dlist[-1])
        else:
            ax.plot(cold_exs[indices], cold_avg[indices], linestyle='--', \
                    label='cold, D = %d' %Dlist[-1])
    
    ax.set_title('SB-LDA, K = %d \n %s' %(K,topicpath))
    ax.set_xlabel('Number of training examples processed')
    ax.set_ylabel('Held-out log-likelihood')
    ax.legend()
    return
